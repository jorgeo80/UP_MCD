# %% [markdown]
# # Análisis de Componentes Principales
# Este ejemplo muestra cómo utilizar PCA para reducir el número de atributos.

# %% [markdown]
# ## Conjunto de datos
# Se utiliza el conjunto de datos de las caras de Olivetti realizado por AT&T
#
# Contiene:
# - 400 ejemplos (caras de personas en diferentes poses)
# - 4096 atributos (pixeles de las imágenes de caras en tamaño 64 x 64)
#
# - 40 sujetos (etiquetas)

# %%
from sklearn.datasets import fetch_olivetti_faces
datos = fetch_olivetti_faces()

# %%
import numpy as np 
import matplotlib.pyplot as plt

import random
idx = random.sample(range(400),20)

imagenes = datos.data[idx,:]
etiquetas = datos.target[idx]

nrows = 2
plt.figure(figsize=(20,4+nrows))

rdatos = random

for j in range(nrows):
    for i, (imagen, etiqueta) in enumerate(zip(imagenes[j:10+j], etiquetas[j:10+j])):
        plt.subplot(nrows, 10, (j*10)+(i + 1))
        plt.imshow(np.reshape(imagen, (64,64)), cmap = plt.cm.gray)
        plt.title('Training: %i\n' % etiqueta, fontsize = 16)

# %% [markdown]
# # Partición de datos

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(datos.data, datos.target, test_size=0.30, random_state=0)

# %% [markdown]
# ## Entrenamiento de un modelo SVM sin PCA
# Se utilizan los 4096 atributos

# %%
from sklearn import svm

modelo = svm.SVC(kernel = 'rbf')
modelo.fit(x_train,y_train)

y_sin_pca = modelo.predict(x_test)

from sklearn.metrics import classification_report

print(classification_report(y_test,y_sin_pca))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         6
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         3
#            3       0.50      1.00      0.67         1
#            4       0.33      0.50      0.40         2
#            5       1.00      1.00      1.00         5
#            6       0.80      0.80      0.80         5
#            7       0.67      0.67      0.67         3
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         4
#           11       0.50      1.00      0.67         1
#           12       0.67      1.00      0.80         2
#           13       1.00      1.00      1.00         3
#           14       1.00      1.00      1.00         5
#           15       0.60      0.60      0.60         5
#           16       0.00      0.00      0.00         0
#           17       1.00      0.50      0.67         6
#           19       1.00      1.00      1.00         4
#           20       1.00      1.00      1.00         1
#           21       1.00      1.00      1.00         2
#           22       0.40      1.00      0.57         2
#           23       1.00      1.00      1.00         2
#           24       1.00      0.50      0.67         2
#           25       1.00      1.00      1.00         4
#           26       1.00      1.00      1.00         4
#           27       1.00      1.00      1.00         1
#           28       1.00      1.00      1.00         3
#           29       1.00      1.00      1.00         5
#           30       1.00      1.00      1.00         4
#           31       1.00      1.00      1.00         4
#           32       1.00      1.00      1.00         3
#           33       1.00      1.00      1.00         2
#           34       1.00      0.50      0.67         6
#           35       1.00      1.00      1.00         1
#           36       1.00      1.00      1.00         4
#           37       1.00      1.00      1.00         3
#           38       1.00      1.00      1.00         1
#           39       0.17      0.33      0.22         3
#
#     accuracy                           0.85       120
#    macro avg       0.86      0.86      0.84       120
# weighted avg       0.91      0.85      0.86       120
# /home/jorgeo80/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Entrenamiento de un SVM con PCA
# Al final, se utilizan 80 componentes principales como atributos del modelo

# %% [markdown]
# ### (1) Obtención de los componentes principales usando PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 80)
pca.fit(x_train)
x_pca = pca.transform(x_train)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()
print(pca.explained_variance_ratio_)
# Out:
# [0.22896348 0.14592546 0.08234502 0.04755187 0.03631723 0.0321201
#  0.02706883 0.02172394 0.0199403  0.0165816  0.01640766 0.01508091
#  0.01298397 0.01157796 0.01089741 0.01045514 0.00965053 0.00849129
#  0.00818336 0.0077229  0.00688084 0.00658604 0.00617279 0.00583665
#  0.00546926 0.00537157 0.00528659 0.00477058 0.00446835 0.00429251
#  0.00393809 0.00385897 0.00359852 0.00356038 0.00338405 0.00327638
#  0.00311404 0.00303491 0.0029031  0.00280424 0.00272368 0.00257651
#  0.00254323 0.0025295  0.00244808 0.00243125 0.00236435 0.00226212
#  0.00220802 0.00215831 0.00211181 0.00208894 0.00196762 0.00191539
#  0.00189505 0.0018604  0.00178439 0.00174375 0.00171867 0.00166128
#  0.0016589  0.00160061 0.0015557  0.00153363 0.00151934 0.00150276
#  0.00143705 0.00141537 0.00141322 0.00138325 0.0013486  0.00130076
#  0.0012743  0.00125926 0.00123105 0.00118771 0.00116552 0.00116123
#  0.00111113 0.00108724]

# %% [markdown]
# ### (2) Entrenamiento de SVM con los componentes principales como atributos

# %%
modelo_pca = svm.SVC(kernel = 'rbf')
modelo_pca.fit(x_pca,y_train)

x_pca_test = pca.transform(x_test)
y_con_pca = modelo_pca.predict(x_pca_test)

print(classification_report(y_test,y_con_pca))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         6
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         1
#            4       0.33      0.50      0.40         2
#            5       1.00      1.00      1.00         5
#            6       0.67      0.80      0.73         5
#            7       0.67      0.67      0.67         3
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         1
#           12       0.67      1.00      0.80         2
#           13       1.00      1.00      1.00         3
#           14       1.00      1.00      1.00         5
#           15       0.60      0.60      0.60         5
#           16       0.00      0.00      0.00         0
#           17       1.00      0.83      0.91         6
#           19       1.00      1.00      1.00         4
#           20       0.50      1.00      0.67         1
#           21       1.00      1.00      1.00         2
#           22       0.67      1.00      0.80         2
#           23       1.00      1.00      1.00         2
#           24       1.00      0.50      0.67         2
#           25       1.00      1.00      1.00         4
#           26       1.00      1.00      1.00         4
#           27       1.00      1.00      1.00         1
#           28       1.00      1.00      1.00         3
#           29       1.00      1.00      1.00         5
#           30       1.00      1.00      1.00         4
#           31       1.00      1.00      1.00         4
#           32       1.00      1.00      1.00         3
#           33       1.00      1.00      1.00         2
#           34       1.00      0.33      0.50         6
#           35       1.00      1.00      1.00         1
#           36       1.00      1.00      1.00         4
#           37       1.00      1.00      1.00         3
#           38       1.00      1.00      1.00         1
#           39       0.29      0.67      0.40         3
#
#     accuracy                           0.87       120
#    macro avg       0.88      0.88      0.86       120
# weighted avg       0.92      0.87      0.87       120
# /home/jorgeo80/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
